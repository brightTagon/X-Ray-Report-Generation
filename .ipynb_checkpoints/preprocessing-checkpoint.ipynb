# %% [markdown]
# # Import Library

# %%
import torch
import torchvision.transforms as T
from torch.utils.data import Dataset, DataLoader
import numpy as np
import pandas as pd
import cv2
import os
import json
import pickle
from nltk.tokenize import sent_tokenize
from PIL import Image
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from utils.utils import *

# %% [markdown]
# # Preprocessing Text

# %% [markdown]
# ## Load and explore GPT2 data

# %%
df_train = pd.read_csv('data/training_set.csv')
df_test = pd.read_csv('data/testing_set.csv')

display(df_train)
# Out:
#                   Image Index  Patient ID  \
# 0     CXR1_1_IM-0001-3001.png           0
# 1     CXR1_1_IM-0001-4001.png           0
# 2      CXR10_IM-0002-1001.png           1
# 3      CXR10_IM-0002-2001.png           1
# 4     CXR100_IM-0002-1001.png           2
# ...                       ...         ...
# 6925  CXR998_IM-2479-1001.png        3824
# 6926  CXR998_IM-2479-2001.png        3824
# 6927  CXR999_IM-2480-1001.png        3825
# 6928  CXR999_IM-2480-2001.png        3825
# 6929  CXR999_IM-2480-3001.png        3825
#
#                                                Findings  \
# 0     startseq The cardiac silhouette and mediastinu...
# 1     startseq The cardiac silhouette and mediastinu...
# 2     startseq The cardiomediastinal silhouette is w...
# 3     startseq The cardiomediastinal silhouette is w...
# 4     startseq Both lungs are clear and expanded. He...
# ...                                                 ...
# 6925  startseq Cardiomediastinal silhouette demonstr...
# ...

# %%
report_ID = {}
sentence_dict = {}
for i, (ID, report, img) in enumerate(zip(df_train["Patient ID"], df_train["Findings"], df_train["Image Index"])):
    if ID not in report_ID:
        report, token = clean_report(cut_startseq_endseq(report).strip().lower())
        report_ID[ID] = {"report": report, "token": token, "img": []}
        
        for sent in token:
            if sent not in sentence_dict:
                sentence_dict[sent] = 0
            sentence_dict[sent] += 1

    report_ID[ID]["img"].append(img)

# %%
id_ = 0
sentence_encoder = {}
sentence_decoder = {}
unclean_sent = []
for sent in sentence_dict:
    if len(sent.split()) == 1:
        print(sentence_dict[sent], sent)
        unclean_sent.append(sent)
        print()
    sentence_encoder[id_] = sent
    sentence_decoder[sent] = id_
    id_ += 1
# Out:
# 2 osteopenia
#
# 13 cardiomegaly
#
# 6 emphysema
#
# 24 chest
#
# 1 hand
#
# 1 ribs
#
# 4 abdomen
#
# 1 ankle
#
# 2 pelvis
#
# 1 xxxx
#
# 1 sternum
#
# 2 granulomas
#
# 1 scoliosis
#
# 1 1933
#
# 1 kub

# %%
pickle.dump(sentence_decoder, open('data/sentence_encoder.pkl', 'wb'))
pickle.dump(sentence_encoder, open('data/sentence_decoder,pkl', 'wb'))

# %%
lengths = []
for ID in report_ID:
    lengths.append(len(report_ID[ID]['token']))
plt.hist(lengths, bins=15)
plt.show()

# %%
for ID in report_ID:
    if len(report_ID[ID]['token']) > 15:
        print(len(report_ID[ID]['token']))
# Out:
# 17
# 18

# %%
for sent in sentence_dict:
    if sentence_dict[sent] == 3:
        print(sent)

# %% [markdown]
# # Load and explore R2GEN data

# %%
annotation = json.loads(open('data/annotation.json', 'r').read())

# %% [markdown]
# ## Sentence Embedding

# %%
##Load Model (Sbert)
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

#Our sentences we like to encode
sentences = df_train.Impression

#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

# %%
print(embeddings.shape)
# Out:
# (6930, 384)

# %% [markdown]
# # Preprocessing Image

# %% [markdown]
# ## Load and explore Images

# %%
img_path = 'data/images'
filenames = os.listdir(img_path)
f = os.path.join(img_path, filenames[0])

img = Image.open(f).resize((256, 256))

# %%
show_img(img, vmin=0, vmax=255)

# %% [markdown]
# ## Normalize and Transforms Images

# %%
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize(mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225])
])

t_img = transform_img(img, transform)
print(t_img.shape)
print(t_img.max(), t_img.min())

test_img = t_img[0].permute(1, 2, 0)
# Out:
# torch.Size([1, 3, 800, 800])
# tensor(1.3328) tensor(-2.0494)

# %%
show_img(test_img, 0, 1, cmap='gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_img.shape
# Out:
# torch.Size([975, 800, 3])

# %% [markdown]
# # DataLoader

# %%
class XRayDataset(Dataset):
    def __init__(self, data, img_dir, transform):
        self.data = data
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.data.iloc[idx, 0])
        image = Image.open(img_path)
        label = self.data.iloc[idx, 2]
        
        image = transform_img(image, self.transform)
        _, label = tokenize_report(label)
        return image, label

# %%
data = XRayDataset(df_train, 'data/images', transform)

# %%
data[0]
# Out:
# (tensor([[[[-1.7069, -1.7069, -1.7069,  ..., -2.0665, -2.0665, -2.0323],
#            [-1.7240, -1.7240, -1.7240,  ..., -2.0837, -2.0665, -2.0665],
#            [-1.7412, -1.7412, -1.7240,  ..., -2.0837, -2.0837, -2.0837],
#            ...,
#            [-0.1657, -0.0972, -0.0458,  ..., -1.9295, -1.9124, -1.9295],
#            [-0.4054, -0.3541, -0.3027,  ..., -1.5870, -1.5699, -1.5699],
#            [-0.1486, -0.0972, -0.0458,  ..., -0.8678, -0.8507, -0.8164]],
#
#           [[-1.6155, -1.6155, -1.6155,  ..., -1.9832, -1.9832, -1.9482],
#            [-1.6331, -1.6331, -1.6331,  ..., -2.0007, -1.9832, -1.9832],
#            [-1.6506, -1.6506, -1.6331,  ..., -2.0007, -2.0007, -2.0007],
#            ...,
#            [-0.0399,  0.0301,  0.0826,  ..., -1.8431, -1.8256, -1.8431],
#            [-0.2850, -0.2325, -0.1800,  ..., -1.4930, -1.4755, -1.4755],
#            [-0.0224,  0.0301,  0.0826,  ..., -0.7577, -0.7402, -0.7052]],
#
# ...
